# %%
python export_sql_to_csv.py --server "MIKASA\SQLEXPRESS" --database Bank_Analytics --transaction-table Transaction_Merged
# Out:
#   Cell In[3], line 1
#     python export_sql_to_csv.py --server "MIKASA\SQLEXPRESS" --database Bank_Analytics --transaction-table Transaction_Merged
#            ^
# SyntaxError: invalid syntax
